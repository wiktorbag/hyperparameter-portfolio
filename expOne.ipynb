# %%
from functions import *
file = pd.read_csv("MementoML.csv")

# %%
small_df = get_mean_metric_dataset_max_params_max_ds(file=file, model="randomForest", metric="auc", number_datasets=4, number_params=8)
small_df.head(36)
# Out:
#     dataset  param_index       auc  rank
# 0      1043            1  0.894560   6.0
# 1      1043            2  0.895119   3.0
# 2      1043            3  0.895297   2.0
# 3      1043            4  0.894249   7.0
# 4      1043            5  0.895088   4.0
# 5      1043            6  0.895433   1.0
# 6      1043            7  0.895046   5.0
# 7      1043            8  0.894001   8.0
# 8      1046            1  0.983564   1.0
# 9      1046            2  0.982815   8.0
# 10     1046            3  0.982876   7.0
# 11     1046            4  0.983285   2.0
# 12     1046            5  0.983155   6.0
# 13     1046            6  0.983258   3.0
# 14     1046            7  0.983235   5.0
# 15     1046            8  0.983245   4.0
# 16     1049            1  0.948787   5.0
# 17     1049            2  0.948837   4.0
# 18     1049            3  0.948620   6.0
# 19     1049            4  0.949731   1.0
# 20     1049            5  0.947936   8.0
# 21     1049            6  0.949031   3.0
# ...

# %%
ASMFO(small_df, 6)
# Out:
# [6, 4, 1, 8, 3, 5]
